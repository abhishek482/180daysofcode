# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishek482/180daysofcode/blob/main/webscrappingnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4  import BeautifulSoup

# %%
response =requests.get('https://www.coursera.org/in/articles/popular-programming-languages')
print(response)
# Out:
# <Response [200]>

# %%
print(response.text)
# Out:
# <!DOCTYPE html><html xmlns:fb="http://ogp.me/ns/fb#" itemtype="http://schema.org" lang="en" dir="ltr" data-color-theme="{{{colorTheme}}}"><head><link rel="preconnect" href="https://d3njjcbhbojbot.cloudfront.net" crossorigin><link rel="preconnect" href="https://browser.sentry-cdn.com" crossorigin><meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=IE7"><meta charset="utf-8"><meta property="og:site_name" content="Coursera"><meta property="fb:admins" content="727836538,4807654"><meta property="fb:app_id" content="823425307723964"><meta name="twitter:site" content="Coursera"><meta name="twitter:app:name:iphone" content="Coursera"><meta name="twitter:app:name:ipad" content="Coursera"><meta name="twitter:app:name:googleplay" content="Coursera"><meta name="twitter:app:id:iphone" content="id736535961"><meta name="twitter:app:id:ipad" content="id736535961"><meta name="twitter:app:id:googleplay" content="org.coursera.android"><meta name="viewport" content="width=device-width, initial-sc
# ...

# %%
soup=BeautifulSoup(response.text,'html.parser')
# Out:
# <!DOCTYPE html>
# ...

# %%
soup=BeautifulSoup(response.text,'html.parser')
print(soup.body)
# Out:
# <body><div id="fb-root"></div><div id="rendered-content"><div class="rc-MetatagsWrapper"><div style="min-height:100vh;background-color:var(--cds-color-neutral-background-primary)"><div class="rc-GlobalPageHeaderContainer css-1ch79bo"><nav class="css-1pf5qcx" data-e2e="page-header" data-testid="page-header-wrapper"><div class="css-u0kpwc"><div class="cds-1 css-j55dmx cds-2 cds-7"><div class="cds-9 css-1kspkkz cds-10"><div class="cds-9 css-1wpuh84 cds-11 cds-grid-item cds-56"><div class="css-az8ufr"><div aria-label="Banner" class="css-j6ha89" role="navigation"><ul class="css-f31nvc"><li class="css-1dswftd"><a aria-current="page" class="cds-119 cds-113 cds-115 css-12x0a78 cds-142" data-click-key="..click.navigation_meta_nav_Individuals" data-click-value='{"href":"https://www.coursera.org/","namespace":{"action":"click","component":"navigation_meta_nav_Individuals"},"schema_type":"FRONTEND"}' data-track="true" data-track-action="click" data-track-component="navigation_meta_nav_Individual
# ...

# %%
print(soup.title)
# Out:
# <title data-rh="true">Popular Programming Languages in 2026 | Coursera</title>

# %%
print(soup.find_all('p'))
# Out:
# [<p>Labor Day starts with $70+ in savings on Coursera Plus. <strong><a class="cds-119 cds-113 cds-115 css-12zefpp cds-142" href="https://www.coursera.org/courseraplus/special/cplus-monthly-august-2026-namer?utm_medium=coursera&amp;utm_source=bluebanner&amp;utm_campaign=2026AugustQ3CplusTentpole">Save 40% for 3 months.</a></strong></p>, <p class="cds-119 css-c80kln cds-121">Letâs explore three popular coding languages and how you can start learning. Are you ready to enter the field of software development but unsure of the programming languages that employers want you to know? This guide can help you know where to start.</p>, <p>For decades now, software engineering and software development have continued to grow rapidly. According to Statista, the software market in India is expected to grow at a rate of 12.24 percent per year <a href="https://www.statista.com/outlook/tmo/software/india#:~:text=Revenue%20is%20expected%20to%20show,US%2412.01bn%20by%202027." rel="noopener noreferrer"
# ...

# %%
import pandas as pd

# Extract text from all <p> tags
paragraphs = [p.get_text() for p in soup.find_all('p')]

# Create a DataFrame from the extracted paragraphs
df_paragraphs = pd.DataFrame(paragraphs, columns=['Paragraph_Text'])

# Display the first few rows of the DataFrame
display(df_paragraphs.head())

# %%
# Save the DataFrame to a CSV file
csv_filename = 'coursera_programming_languages_paragraphs.csv'
df_paragraphs.to_csv(csv_filename, index=False)

print(f"Data successfully exported to {csv_filename}")

# %% [markdown]
# This code snippet first extracts the text content from all `<p>` tags found by BeautifulSoup. It then creates a pandas DataFrame with a single column named 'Paragraph_Text' containing these extracted texts. Finally, it saves this DataFrame to a CSV file named `coursera_programming_languages_paragraphs.csv` without including the DataFrame index.
